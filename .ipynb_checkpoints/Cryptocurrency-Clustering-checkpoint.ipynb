# %%
# Dependencies.
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Preparation

# %%
#Read crypto_data.csv into pandas
crypto_data = "resources/data/crypto_data.csv"
crypto_df = pd.read_csv(crypto_data)
crypto_df.head(10)
# Out:
#   Unnamed: 0   CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1        365    365Coin       X11       True   PoW/PoS              NaN
# 2        404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3        611  SixEleven   SHA-256       True       PoW              NaN
# 4        808        808   SHA-256       True   PoW/PoS     0.000000e+00
# 5       1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 6       2015  2015 coin       X11       True   PoW/PoS              NaN
# 7        BTC    Bitcoin   SHA-256       True       PoW     1.792718e+07
# 8        ETH   Ethereum    Ethash       True       PoW     1.076842e+08
# 9        LTC   Litecoin    Scrypt       True       PoW     6.303924e+07
#
#   TotalCoinSupply
# 0              42
# 1      2300000000
# 2       532000000
# 3          611000
# 4               0
# 5    314159265359
# 6               0
# 7        21000000
# 8               0
# 9        84000000

# %%
#Discard all cryptocurrencies that are not being traded
crypto_df = crypto_df[crypto_df['IsTrading'] == True]
crypto_df.head(10)
# Out:
#   Unnamed: 0   CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1        365    365Coin       X11       True   PoW/PoS              NaN
# 2        404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3        611  SixEleven   SHA-256       True       PoW              NaN
# 4        808        808   SHA-256       True   PoW/PoS     0.000000e+00
# 5       1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 6       2015  2015 coin       X11       True   PoW/PoS              NaN
# 7        BTC    Bitcoin   SHA-256       True       PoW     1.792718e+07
# 8        ETH   Ethereum    Ethash       True       PoW     1.076842e+08
# 9        LTC   Litecoin    Scrypt       True       PoW     6.303924e+07
#
#   TotalCoinSupply
# 0              42
# 1      2300000000
# 2       532000000
# 3          611000
# 4               0
# 5    314159265359
# 6               0
# 7        21000000
# 8               0
# 9        84000000

# %%
# Keep all the cryptocurrencies that have a working algorithm.
crypto_df = crypto_df.dropna(subset=['Algorithm'])
crypto_df.head(10)
# Out:
#   Unnamed: 0   CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1        365    365Coin       X11       True   PoW/PoS              NaN
# 2        404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3        611  SixEleven   SHA-256       True       PoW              NaN
# 4        808        808   SHA-256       True   PoW/PoS     0.000000e+00
# 5       1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 6       2015  2015 coin       X11       True   PoW/PoS              NaN
# 7        BTC    Bitcoin   SHA-256       True       PoW     1.792718e+07
# 8        ETH   Ethereum    Ethash       True       PoW     1.076842e+08
# 9        LTC   Litecoin    Scrypt       True       PoW     6.303924e+07
#
#   TotalCoinSupply
# 0              42
# 1      2300000000
# 2       532000000
# 3          611000
# 4               0
# 5    314159265359
# 6               0
# 7        21000000
# 8               0
# 9        84000000

# %%
#Drop IsTrading column from the dataframe

crypto_df.drop(columns=['IsTrading'], inplace=True)
crypto_df
# Out:
#      Unnamed: 0                CoinName       Algorithm ProofType  \
# 0            42                 42 Coin          Scrypt   PoW/PoS
# 1           365                 365Coin             X11   PoW/PoS
# 2           404                 404Coin          Scrypt   PoW/PoS
# 3           611               SixEleven         SHA-256       PoW
# 4           808                     808         SHA-256   PoW/PoS
# 5          1337               EliteCoin             X13   PoW/PoS
# 6          2015               2015 coin             X11   PoW/PoS
# 7           BTC                 Bitcoin         SHA-256       PoW
# 8           ETH                Ethereum          Ethash       PoW
# 9           LTC                Litecoin          Scrypt       PoW
# 10         DASH                    Dash             X11   PoW/PoS
# 11          XMR                  Monero  CryptoNight-V7       PoW
# 12          ETC        Ethereum Classic          Ethash       PoW
# 13          ZEC                   ZCash        Equihash       PoW
# 14          BTS               Bitshares         SHA-512       PoS
# 15          DGB                DigiByte        Multiple       PoW
# 16         BTCD             BitcoinDark         SHA-256   PoW/PoS
# 17        CRAIG              CraigsCoin             X11       PoS
# 18          XBS                Bitstake             X11   PoW/PoS
# 19          XPY                 PayCoin         SHA-256       PoS
# 20          PRC             ProsperCoin          Scrypt       PoW
# 21          YBC                  YbCoin        Multiple       PoS
# 22         DANK                DarkKush             X13   PoW/PoS
# 23         GIVE                GiveCoin             X11       PoW
# 24         KOBO                KoboCoin             X15   PoW/PoS
# 25           DT               DarkToken           NIST5   PoW/PoS
# 26         CETI              CETUS Coin          Scrypt   PoW/PoS
# 27          SPR              Spreadcoin             X11       PoW
# 28         WOLF           Insanity Coin             X11       PoW
# 29        ACOIN                   ACoin         SHA-256       PoW
# ...         ...                     ...             ...       ...
# 1212        AHT                 Ahoolee          Ethash       PoW
# 1213        RCC           Reality Clash          Ethash       PoW
# 1214        OXY                 Oxycoin            DPoS      DPoS
# 1216       KAPU                    Kapu            DPoS      DPoS
# 1217       GRFT        Graft Blockchain     CryptoNight   PoW/PoS
# 1218        MNZ                 Monaize        Equihash  PoW/DPoW
# 1221       SCRM                  Scorum            DPoS      DPoS
# 1222        LWF  Local World Forwarders            DPoS      DPoS
# 1223        ILT                  iOlite          Ethash       PoW
# 1224        ADM                 Adamant            DPoS      DPoS
# 1225        UPX                  uPlexa     CryptoNight       PoW
# 1226        TCH               TigerCash         SHA-256       PoS
# 1228        TIP          Tip Blockchain            DPoS       PoS
# 1229       DTEP                  DECOIN             X11       PoS
# 1230      WAVES                   Waves      Leased POS      LPoS
# 1231       PART                 Particl             PoS       PoS
# 1232        SLX                   Slate      Slatechain       PoW
# 1234        BTT              BitTorrent           TRC10      DPoS
# 1235        CHI                    XAYA       NeoScrypt       PoW
# 1237        NXT                     Nxt             PoS  PoS/LPoS
# 1238       ZEPH                  ZEPHYR         SHA-256      DPoS
# 1239        XQN                Quotient          Scrypt   PoW/PoS
# 1240       NETC             NetworkCoin             X13   PoW/PoS
# 1241       VPRC              VapersCoin          Scrypt       PoW
# 1242        GAP                 Gapcoin          Scrypt   PoW/PoS
# 1243       SERO              Super Zero          Ethash       PoW
# 1244        UOS                     UOS         SHA-256      DPoI
# 1245        BDX                  Beldex     CryptoNight       PoW
# 1246        ZEN                 Horizen        Equihash       PoW
# 1247        XBC             BitcoinPlus          Scrypt       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# 4        0.000000e+00               0
# 5        2.927942e+10    314159265359
# 6                 NaN               0
# 7        1.792718e+07        21000000
# 8        1.076842e+08               0
# 9        6.303924e+07        84000000
# 10       9.031294e+06        22000000
# 11       1.720114e+07               0
# 12       1.133597e+08       210000000
# 13       7.383056e+06        21000000
# 14       2.741570e+09      3600570502
# 15       1.140622e+10     21000000000
# 16       1.288862e+06        22000000
# 17                NaN        30000000
# 18       0.000000e+00         1300000
# 19       1.199533e+07        12500000
# 20       5.768310e+06        21000000
# 21                NaN       200000000
# 22                NaN         3000000
# 23                NaN       500000000
# 24       2.554254e+07       350000000
# 25                NaN               0
# 26                NaN               0
# 27       1.114973e+07        20000000
# 28                NaN        50000000
# 29       0.000000e+00         1600000
# ...               ...             ...
# 1212              NaN       100000000
# 1213     2.448794e+07        24487944
# 1214     1.122382e+09               0
# 1216              NaN       115000000
# 1217              NaN      1844674400
# 1218              NaN       257142857
# 1221              NaN        20000000
# 1222              NaN       100000000
# 1223     0.000000e+00      1000000000
# 1224              NaN       200000000
# 1225              NaN     10500000000
# 1226     1.000000e+09      1000000000
# 1228              NaN      1000000000
# 1229              NaN       140000000
# 1230     1.000000e+08       100000000
# 1231     9.283138e+06         8634140
# 1232              NaN       950000000
# 1234     9.899887e+11    990000000000
# 1235              NaN        77303932
# 1237     1.000000e+09      1000000000
# 1238     2.000000e+09      2000000000
# 1239              NaN               0
# 1240              NaN          400000
# 1241              NaN     42750000000
# 1242     1.493105e+07       250000000
# 1243              NaN      1000000000
# 1244              NaN      1000000000
# 1245     9.802226e+08      1400222610
# 1246     7.296538e+06        21000000
# 1247     1.283270e+05         1000000
#
# [1144 rows x 6 columns]

# %%
#Remove all rows that have at least one null value
crypto_df.dropna(inplace=True)
crypto_df.head(10)
# Out:
#    Unnamed: 0          CoinName       Algorithm ProofType  TotalCoinsMined  \
# 0          42           42 Coin          Scrypt   PoW/PoS     4.199995e+01
# 2         404           404Coin          Scrypt   PoW/PoS     1.055185e+09
# 4         808               808         SHA-256   PoW/PoS     0.000000e+00
# 5        1337         EliteCoin             X13   PoW/PoS     2.927942e+10
# 7         BTC           Bitcoin         SHA-256       PoW     1.792718e+07
# 8         ETH          Ethereum          Ethash       PoW     1.076842e+08
# 9         LTC          Litecoin          Scrypt       PoW     6.303924e+07
# 10       DASH              Dash             X11   PoW/PoS     9.031294e+06
# 11        XMR            Monero  CryptoNight-V7       PoW     1.720114e+07
# 12        ETC  Ethereum Classic          Ethash       PoW     1.133597e+08
#
#    TotalCoinSupply
# 0               42
# 2        532000000
# 4                0
# 5     314159265359
# 7         21000000
# 8                0
# 9         84000000
# 10        22000000
# 11               0
# 12       210000000

# %%
#Filter cryptocurrencies that have been mined
crypto_df = crypto_df[crypto_df['TotalCoinsMined'] > 0]
crypto_df
# Out:
#      Unnamed: 0          CoinName        Algorithm       ProofType  \
# 0            42           42 Coin           Scrypt         PoW/PoS
# 2           404           404Coin           Scrypt         PoW/PoS
# 5          1337         EliteCoin              X13         PoW/PoS
# 7           BTC           Bitcoin          SHA-256             PoW
# 8           ETH          Ethereum           Ethash             PoW
# 9           LTC          Litecoin           Scrypt             PoW
# 10         DASH              Dash              X11         PoW/PoS
# 11          XMR            Monero   CryptoNight-V7             PoW
# 12          ETC  Ethereum Classic           Ethash             PoW
# 13          ZEC             ZCash         Equihash             PoW
# 14          BTS         Bitshares          SHA-512             PoS
# 15          DGB          DigiByte         Multiple             PoW
# 16         BTCD       BitcoinDark          SHA-256         PoW/PoS
# 19          XPY           PayCoin          SHA-256             PoS
# 20          PRC       ProsperCoin           Scrypt             PoW
# 24         KOBO          KoboCoin              X15         PoW/PoS
# 27          SPR        Spreadcoin              X11             PoW
# 37          ARG          Argentum           Scrypt             PoW
# 39          AUR       Aurora Coin           Scrypt         PoW/PoS
# 42          BLU          BlueCoin           Scrypt         PoW/PoS
# 44          XMY        MyriadCoin         Multiple             PoW
# 45         MOON          MoonCoin           Scrypt             PoW
# 46          ZET          ZetaCoin          SHA-256             PoW
# 47          SXC           SexCoin           Scrypt             PoW
# 48          QTL           Quatloo           Scrypt             PoW
# 49         ENRG        EnergyCoin           Scrypt         PoW/PoS
# 50          QRK         QuarkCoin            Quark             PoW
# 51          RIC           Riecoin          Groestl             PoW
# 52          DGC      Digitalcoin            Scrypt             PoW
# 54          BTB            BitBar           Scrypt         PoW/PoS
# ...         ...               ...              ...             ...
# 1181       SMLY        SmileyCoin           Scrypt             PoW
# 1185         MI        XiaoMiCoin           Scrypt         PoW/PoS
# 1186        GRS       Groestlcoin          Groestl             PoW
# 1187        CPC         CapriCoin              X11         PoW/PoS
# 1188       CLUB          ClubCoin           Scrypt         PoW/PoS
# 1189       RADS            Radium              PoS             PoS
# 1190        BTA              Bata           Scrypt             PoW
# 1191        PAK           Pakcoin           Scrypt             PoW
# 1192        CRB        Creditbit               X11  Proof of Trust
# 1193         OK            OKCash          SHA-256         PoW/PoS
# 1194        LSK              Lisk             DPoS            DPoS
# 1195        XHI            HiCoin           Scrypt             PoS
# 1196        XWC         WhiteCoin           Scrypt         PoW/PoS
# 1198        FSC    FriendshipCoin        NeoScrypt         PoW/PoS
# 1201          J          JoinCoin         Multiple             PoW
# 1202        TRI    Triangles Coin              X13         PoW/PoS
# 1204     VOLLAR            Vollar  Equihash+Scrypt             PoW
# 1211        EOS               EOS             DPoS            DPoS
# 1213        RCC     Reality Clash           Ethash             PoW
# 1214        OXY           Oxycoin             DPoS            DPoS
# 1226        TCH         TigerCash          SHA-256             PoS
# 1230      WAVES             Waves       Leased POS            LPoS
# 1231       PART           Particl              PoS             PoS
# 1234        BTT        BitTorrent            TRC10            DPoS
# 1237        NXT               Nxt              PoS        PoS/LPoS
# 1238       ZEPH            ZEPHYR          SHA-256            DPoS
# 1242        GAP           Gapcoin           Scrypt         PoW/PoS
# 1245        BDX            Beldex      CryptoNight             PoW
# 1246        ZEN           Horizen         Equihash             PoW
# 1247        XBC       BitcoinPlus           Scrypt             PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 2        1.055185e+09       532000000
# 5        2.927942e+10    314159265359
# 7        1.792718e+07        21000000
# 8        1.076842e+08               0
# 9        6.303924e+07        84000000
# 10       9.031294e+06        22000000
# 11       1.720114e+07               0
# 12       1.133597e+08       210000000
# 13       7.383056e+06        21000000
# 14       2.741570e+09      3600570502
# 15       1.140622e+10     21000000000
# 16       1.288862e+06        22000000
# 19       1.199533e+07        12500000
# 20       5.768310e+06        21000000
# 24       2.554254e+07       350000000
# 27       1.114973e+07        20000000
# 37       1.220580e+07        64000000
# 39       1.813510e+07        16768584
# 42       6.354239e+08               0
# 44       1.688254e+09      2000000000
# 45       8.800000e+01    384000000000
# 46       1.702044e+08       169795588
# 47       1.289410e+08       250000000
# 48       7.357795e+06       100000000
# 49       1.230628e+08               0
# 50       2.595572e+08       247000000
# 51       4.954859e+07        84000000
# 52       3.344299e+07        48166000
# 54       4.257948e+04          500000
# ...               ...             ...
# 1181     2.958399e+10     50000000000
# 1185     4.043165e+08       400000000
# 1186     7.329820e+07       105000000
# 1187     2.013643e+08       208000000
# 1188     1.036219e+08       160000000
# 1189     3.821246e+06         9000000
# 1190     5.052556e+06         5000000
# 1191     6.968446e+07       182000000
# 1192     1.690102e+07        16504333
# 1193     7.467606e+07       105000000
# 1194     1.200121e+08       159918400
# 1195     1.000024e+10     10008835635
# 1196     2.520056e+08       300000000
# 1198     1.120385e+06        60168145
# 1201     3.332922e+06         2800000
# 1202     1.407778e+05          120000
# 1204     1.000000e+08      2100000000
# 1211     1.020545e+09               0
# 1213     2.448794e+07        24487944
# 1214     1.122382e+09               0
# 1226     1.000000e+09      1000000000
# 1230     1.000000e+08       100000000
# 1231     9.283138e+06         8634140
# 1234     9.899887e+11    990000000000
# 1237     1.000000e+09      1000000000
# 1238     2.000000e+09      2000000000
# 1242     1.493105e+07       250000000
# 1245     9.802226e+08      1400222610
# 1246     7.296538e+06        21000000
# 1247     1.283270e+05         1000000
#
# [532 rows x 6 columns]

# %%
# Create a new DataFrame that holds only the coin names.
coins_df = pd.DataFrame(crypto_df['CoinName'])
coins_df
# Out:
#               CoinName
# 0              42 Coin
# 2              404Coin
# 5            EliteCoin
# 7              Bitcoin
# 8             Ethereum
# 9             Litecoin
# 10                Dash
# 11              Monero
# 12    Ethereum Classic
# 13               ZCash
# 14           Bitshares
# 15            DigiByte
# 16         BitcoinDark
# 19             PayCoin
# 20         ProsperCoin
# 24            KoboCoin
# 27          Spreadcoin
# 37            Argentum
# 39         Aurora Coin
# 42            BlueCoin
# 44          MyriadCoin
# 45            MoonCoin
# 46            ZetaCoin
# 47             SexCoin
# 48             Quatloo
# 49          EnergyCoin
# 50           QuarkCoin
# 51             Riecoin
# 52        Digitalcoin
# 54              BitBar
# ...                ...
# 1181        SmileyCoin
# 1185        XiaoMiCoin
# 1186       Groestlcoin
# 1187         CapriCoin
# 1188          ClubCoin
# 1189            Radium
# 1190              Bata
# 1191           Pakcoin
# 1192        Creditbit
# 1193            OKCash
# 1194              Lisk
# 1195            HiCoin
# 1196         WhiteCoin
# 1198    FriendshipCoin
# 1201          JoinCoin
# 1202    Triangles Coin
# 1204            Vollar
# 1211               EOS
# 1213     Reality Clash
# 1214           Oxycoin
# 1226         TigerCash
# 1230             Waves
# 1231           Particl
# 1234        BitTorrent
# 1237               Nxt
# 1238            ZEPHYR
# 1242           Gapcoin
# 1245            Beldex
# 1246           Horizen
# 1247       BitcoinPlus
#
# [532 rows x 1 columns]

# %%
#Drop'CoinName' from the orginal dataframe since it cannot be used by the clustering Algorithm
crypto_df = crypto_df.drop(columns=["CoinName", "Unnamed: 0"])
crypto_df
# Out:
#             Algorithm       ProofType  TotalCoinsMined TotalCoinSupply
# 0              Scrypt         PoW/PoS     4.199995e+01              42
# 2              Scrypt         PoW/PoS     1.055185e+09       532000000
# 5                 X13         PoW/PoS     2.927942e+10    314159265359
# 7             SHA-256             PoW     1.792718e+07        21000000
# 8              Ethash             PoW     1.076842e+08               0
# 9              Scrypt             PoW     6.303924e+07        84000000
# 10                X11         PoW/PoS     9.031294e+06        22000000
# 11     CryptoNight-V7             PoW     1.720114e+07               0
# 12             Ethash             PoW     1.133597e+08       210000000
# 13           Equihash             PoW     7.383056e+06        21000000
# 14            SHA-512             PoS     2.741570e+09      3600570502
# 15           Multiple             PoW     1.140622e+10     21000000000
# 16            SHA-256         PoW/PoS     1.288862e+06        22000000
# 19            SHA-256             PoS     1.199533e+07        12500000
# 20             Scrypt             PoW     5.768310e+06        21000000
# 24                X15         PoW/PoS     2.554254e+07       350000000
# 27                X11             PoW     1.114973e+07        20000000
# 37             Scrypt             PoW     1.220580e+07        64000000
# 39             Scrypt         PoW/PoS     1.813510e+07        16768584
# 42             Scrypt         PoW/PoS     6.354239e+08               0
# 44           Multiple             PoW     1.688254e+09      2000000000
# 45             Scrypt             PoW     8.800000e+01    384000000000
# 46            SHA-256             PoW     1.702044e+08       169795588
# 47             Scrypt             PoW     1.289410e+08       250000000
# 48             Scrypt             PoW     7.357795e+06       100000000
# 49             Scrypt         PoW/PoS     1.230628e+08               0
# 50              Quark             PoW     2.595572e+08       247000000
# 51            Groestl             PoW     4.954859e+07        84000000
# 52             Scrypt             PoW     3.344299e+07        48166000
# 54             Scrypt         PoW/PoS     4.257948e+04          500000
# ...               ...             ...              ...             ...
# 1181           Scrypt             PoW     2.958399e+10     50000000000
# 1185           Scrypt         PoW/PoS     4.043165e+08       400000000
# 1186          Groestl             PoW     7.329820e+07       105000000
# 1187              X11         PoW/PoS     2.013643e+08       208000000
# 1188           Scrypt         PoW/PoS     1.036219e+08       160000000
# 1189              PoS             PoS     3.821246e+06         9000000
# 1190           Scrypt             PoW     5.052556e+06         5000000
# 1191           Scrypt             PoW     6.968446e+07       182000000
# 1192              X11  Proof of Trust     1.690102e+07        16504333
# 1193          SHA-256         PoW/PoS     7.467606e+07       105000000
# 1194             DPoS            DPoS     1.200121e+08       159918400
# 1195           Scrypt             PoS     1.000024e+10     10008835635
# 1196           Scrypt         PoW/PoS     2.520056e+08       300000000
# 1198        NeoScrypt         PoW/PoS     1.120385e+06        60168145
# 1201         Multiple             PoW     3.332922e+06         2800000
# 1202              X13         PoW/PoS     1.407778e+05          120000
# 1204  Equihash+Scrypt             PoW     1.000000e+08      2100000000
# 1211             DPoS            DPoS     1.020545e+09               0
# 1213           Ethash             PoW     2.448794e+07        24487944
# 1214             DPoS            DPoS     1.122382e+09               0
# 1226          SHA-256             PoS     1.000000e+09      1000000000
# 1230       Leased POS            LPoS     1.000000e+08       100000000
# 1231              PoS             PoS     9.283138e+06         8634140
# 1234            TRC10            DPoS     9.899887e+11    990000000000
# 1237              PoS        PoS/LPoS     1.000000e+09      1000000000
# 1238          SHA-256            DPoS     2.000000e+09      2000000000
# 1242           Scrypt         PoW/PoS     1.493105e+07       250000000
# 1245      CryptoNight             PoW     9.802226e+08      1400222610
# 1246         Equihash             PoW     7.296538e+06        21000000
# 1247           Scrypt             PoS     1.283270e+05         1000000
#
# [532 rows x 4 columns]

# %%
#Convert text features to numeric data
X = pd.get_dummies(crypto_df, columns=['Algorithm', 'ProofType'])
X.head(10)
# Out:
#     TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 0      4.199995e+01              42                                 0
# 2      1.055185e+09       532000000                                 0
# 5      2.927942e+10    314159265359                                 0
# 7      1.792718e+07        21000000                                 0
# 8      1.076842e+08               0                                 0
# 9      6.303924e+07        84000000                                 0
# 10     9.031294e+06        22000000                                 0
# 11     1.720114e+07               0                                 0
# 12     1.133597e+08       210000000                                 0
# 13     7.383056e+06        21000000                                 0
#
#     Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 0               0                  0                   0                0
# 2               0                  0                   0                0
# 5               0                  0                   0                0
# 7               0                  0                   0                0
# 8               0                  0                   0                0
# 9               0                  0                   0                0
# 10              0                  0                   0                0
# 11              0                  0                   0                0
# 12              0                  0                   0                0
# 13              0                  0                   0                0
#
#     Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  ...  \
# 0                   0                  0              0  ...
# 2                   0                  0              0  ...
# 5                   0                  0              0  ...
# 7                   0                  0              0  ...
# 8                   0                  0              0  ...
# 9                   0                  0              0  ...
# 10                  0                  0              0  ...
# 11                  0                  0              0  ...
# 12                  0                  0              0  ...
# 13                  0                  0              0  ...
#
#     ProofType_PoW/PoS  ProofType_PoW/PoS   ProofType_PoW/PoW  \
# 0                   1                   0                  0
# 2                   1                   0                  0
# 5                   1                   0                  0
# 7                   0                   0                  0
# 8                   0                   0                  0
# 9                   0                   0                  0
# 10                  1                   0                  0
# 11                  0                   0                  0
# 12                  0                   0                  0
# 13                  0                   0                  0
#
#     ProofType_PoW/nPoS  ProofType_Pos  ProofType_Proof of Authority  \
# 0                    0              0                             0
# 2                    0              0                             0
# 5                    0              0                             0
# 7                    0              0                             0
# 8                    0              0                             0
# 9                    0              0                             0
# 10                   0              0                             0
# 11                   0              0                             0
# 12                   0              0                             0
# 13                   0              0                             0
#
#     ProofType_Proof of Trust  ProofType_TPoS  ProofType_Zero-Knowledge Proof  \
# 0                          0               0                               0
# 2                          0               0                               0
# 5                          0               0                               0
# 7                          0               0                               0
# 8                          0               0                               0
# 9                          0               0                               0
# 10                         0               0                               0
# 11                         0               0                               0
# 12                         0               0                               0
# 13                         0               0                               0
#
#     ProofType_dPoW/PoW
# 0                    0
# 2                    0
# 5                    0
# 7                    0
# 8                    0
# 9                    0
# 10                   0
# 11                   0
# 12                   0
# 13                   0
#
# [10 rows x 98 columns]

# %%
#Standardize the dataset using sklearn StandardScaler
X_scaled = StandardScaler().fit_transform(X)
X_scaled
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, float64, object were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype uint8, float64, object were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# array([[-0.11710817, -0.1528703 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.09396955, -0.145009  , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [ 0.52494561,  4.48942416, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        ...,
#        [-0.09561336, -0.13217937, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11694817, -0.15255998, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11710536, -0.15285552, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ]])

# %% [markdown]
# ## Dimensionality Reduction

# %%
# Reduce dimension with PCA 
pca = PCA(n_components=.90)
principal_compnenets = pca.fit_transform(X_scaled)
principal_compnenets.shape
# Out:
# (532, 74)

# %%
# Variance levels display of the principal_components line above
print(pca.explained_variance_.sum())
# Out:
# 88.47283457566155

# %%
# Reduce dimensions with t-SNE
tsne = TSNE(perplexity=50)
tsne_feature = tsne.fit_transform(principal_compnenets)
tsne_feature.shape
# Out:
# (532, 2)

# %% [markdown]
# ## Clustering with K-Means

# %%
# Plot T-SNE features
X = tsne_feature[:,0]
y = tsne_feature[:,1]

# Display plt
plt.scatter(X,y)
plt.title("T-SNE Feature Clusters")
plt.show()

# %%
# Identify cluster with k-means
inertia = []
k = list(range(1,11))

for i in k:
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(principal_components)
    inertia.append(kmeans.inertia_)

# %%
# Create the elbow curve
elbow_df = pd.DataFrame({"k": k, "inertia": inertia})
elbow_df.plot.line(x="k", y="inertia")
plt.xlabel("K Means")
plt.ylabel("Inertia")
plt.title("Elbow Plot")
plt.show()
